# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\At\Desktop\Retail data .csv")

df.head(101)

# print(df.isnull().sum())
# print(df.duplicated().sum())
# df = df.drop_duplicates()
# df = df.dropna()
# print(df.isnull().sum())
# print(df.duplicated().sum())



dim_age_group = pd.DataFrame({
    'age_group_id': [1, 2, 3, 4, 5],
    'age_group': [
        '18-24',
        '25-34',
        '35-44',
        '45-54',
        '55+'
    ]
})
print(dim_age_group)

dim_gender = pd.DataFrame({
    'gender_id': [1, 2, 3],
    'gender': ['Male', 'Female', 'Other']
})



print(dim_gender)

dim_customer_segment = pd.DataFrame({
    'customer_segment_id': [1, 2, 3, 4],
    'customer_segment': [
        'Loyal',
        'New',
        'VIP',
        'Returning'
    ]
})

print(dim_customer_segment)

dim_preferred_channel = pd.DataFrame({
    'preferred_channel_id': [1, 2, 3],
    'preferred_channel': [
        'Online',
        'Mobile App',
        'In-Store'
    ]
})

print(dim_preferred_channel)

dim_region = pd.DataFrame({
    'region_id': [1, 2, 3, 4],
    'region': [
        'North',
        'South',
        'East',
        'West'
    ]
})

print(dim_region)




print(dim_age_group)

print(dim_gender)
print(dim_customer_segment)
print(dim_preferred_channel)
print(dim_region)
# Out:
#    age_group_id age_group
# 0             1     18-24
# 1             2     25-34
# 2             3     35-44
# 3             4     45-54
# 4             5       55+
#    gender_id  gender
# 0          1    Male
# 1          2  Female
# 2          3   Other
#    customer_segment_id customer_segment
# 0                    1            Loyal
# 1                    2              New
# 2                    3              VIP
# 3                    4        Returning
#    preferred_channel_id preferred_channel
# 0                     1            Online
# 1                     2        Mobile App
# 2                     3          In-Store
#    region_id region
# 0          1  North
# 1          2  South
# 2          3   East
# 3          4   West
#    age_group_id age_group
# 0             1     18-24
# 1             2     25-34
# 2             3     35-44
# 3             4     45-54
# 4             5       55+
#    gender_id  gender
# 0          1    Male
# 1          2  Female
# ...
